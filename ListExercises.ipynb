# %%
#Exercise 1

#1
mylist = ["Table", "Chair", "Shelf", "Sofa"]

#2
print (mylist)

#3
print(mylist [:2])

#4
for huonekalut in mylist:
    if huonekalut == "Sofa":
        print(huonekalut)
# Out:
# ['Table', 'Chair', 'Shelf', 'Sofa']
# ['Table', 'Chair']
# Sofa

# %%
#Exercise 2
import random

#1
thrownDiceNumbers = [0, 0, 0, 0, 0]

#2
for i in range(5):
    thrownDiceNumbers[i] = random.randint(1, 6)

#3
print(thrownDiceNumbers)

#4
summa = sum(thrownDiceNumbers)
print(summa)

#5
suurin = max(thrownDiceNumbers)
print(suurin)
# Out:
# [6, 2, 4, 4, 1]
# 17
# 6
